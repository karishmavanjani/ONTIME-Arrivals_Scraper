# %%
import pandas as pd
import re
import sys
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
#from bs4 import BeautifulSoup
import re
import pandas as pd
#from tabulate import tabulate
import os
#import chromedriver_binary
import numpy as np
import datetime as dt
from dateutil.parser import parse

# %%
def analysis(input_fn,output_fn):
    AS= pd.read_csv(input_fn,skiprows=7)
    df= pd.DataFrame(AS)
    print(len(df))
    df.loc[df['Actual Arrival Time']=='00:00']
    df= df.dropna(subset=['Scheduled Arrival Time','Actual Arrival Time'])
    df.head()
    #Rename it to scheduled arrival date
    df.rename(columns = {'Date (MM/DD/YYYY)':'Scheduled Date'}, inplace = True) 
    df['Scheduled Date']= pd.to_datetime(df['Scheduled Date'])
    type(df['Scheduled Date'][0])
    # Makea new column called actual arrival date 
    df['Actual Arrival Date'] = df['Scheduled Date']
    df['Actual Arrival Time']= df['Actual Arrival Time'].str.replace('24:00','00:00')
    df['Scheduled Arrival Time']= df['Scheduled Arrival Time'].str.replace('24:00','00:00')
    df.loc[df['Actual Arrival Time']=='00:00','Actual Arrival Date']+=dt.timedelta(days=1)
    df.loc[df['Scheduled Arrival Time']=='00:00','Scheduled Date']+=dt.timedelta(days=1)
    df['Actual Arrival Date']= df['Actual Arrival Date'].dt.strftime('%Y-%m-%d')
    df['Scheduled Date']= df['Scheduled Date'].dt.strftime('%Y-%m-%d')
    df['Actual Arrival']=df['Actual Arrival Date'] + ' ' + df['Actual Arrival Time']
    df['Scheduled Arrival']=df['Scheduled Date'] + ' ' + df['Scheduled Arrival Time']
    df.loc[df['Actual Arrival Time']=='00:00']
    FMT = '%Y-%m-%d %H:%M'
    df['Scheduled Arrival']= pd.to_datetime(df['Scheduled Arrival'], format=FMT)
    df['Actual Arrival']= pd.to_datetime(df['Actual Arrival'], format=FMT)
    df['Difference']= (df['Scheduled Arrival']-df['Actual Arrival']).astype('timedelta64[m]')
    #Count number of flights with Scheduled Arrival Time higher than Actual Arrival or flights that arrived early in 2019
    Count_2019=df[df['Actual Arrival Date'].str.contains("2019")]
    df19= pd.DataFrame(Count_2019)
    Total_19=len(df19)
    Twenty_Mins_Early_19= len(df19[df19['Difference'] > 20.0])
    Early_Arrivals_19= len(df19[df19['Difference'] > 0])
    print("Total Alaska Airlines flights that landed at JFK in 2019:",Total_19)
    print("Flights that arrived early in 2019:",Early_Arrivals_19)
    print("Flights that arrived more than 20 mins early in 2019:",Twenty_Mins_Early_19)
    #Count number of flights with Scheduled Arrival Time higher than Actual Arrival or flights that arrived early in 2018
    Count_2018=df[df['Actual Arrival Date'].str.contains("2018")]
    df18= pd.DataFrame(Count_2018)
    Total_18=len(df18)
    Twenty_Mins_Early_18= len(df18[df18['Difference'] > 20.0])
    Early_Arrivals_18= len(df18[df18['Difference'] > 0])
    print("Total Alaska Airlines flights that landed at JFK in 2018:",Total_18)
    print("Flights that arrived early in 2018:",Early_Arrivals_18)
    print("Flights that arrived more than 20 mins early in 2018:",Twenty_Mins_Early_18)
    #Count number of flights with Scheduled Arrival Time higher than Actual Arrival or flights that arrived early in 2017
    Count_2017=df[df['Actual Arrival Date'].str.contains("2017")]
    df17= pd.DataFrame(Count_2017)
    Total_17=len(df17)
    Twenty_Mins_Early_17= len(df17[df17['Difference'] > 20.0])
    Early_Arrivals_17= len(df17[df17['Difference'] > 0])
    print("Total Alaska Airlines flights that landed at JFK in 2017:",Total_17)
    print("Flights that arrived early in 2017:",Early_Arrivals_17)
    print("Flights that arrived more than 20 mins early in 2017:",Twenty_Mins_Early_17)
    #Count number of flights with Scheduled Arrival Time higher than Actual Arrival or flights that arrived early in 2016
    Count_2016=df[df['Actual Arrival Date'].str.contains("2016")]
    df16= pd.DataFrame(Count_2016)
    Total_16=len(df16)
    Twenty_Mins_Early_16= len(df16[df16['Difference'] > 20.0])
    Early_Arrivals_16= len(df16[df16['Difference'] > 0])
    print("Total Alaska Airlines flights that landed at JFK in 2016:",Total_16)
    print("Flights that arrived early in 2016:",Early_Arrivals_16)
    print("Flights that arrived more than 20 mins early in 2016:",Twenty_Mins_Early_16)
    #Count number of flights with Scheduled Arrival Time higher than Actual Arrival or flights that arrived early in 2015
    Count_2015=df[df['Actual Arrival Date'].str.contains("2015")]
    df15= pd.DataFrame(Count_2015)
    Total_15=len(df15)
    Twenty_Mins_Early_15= len(df15[df15['Difference'] > 20.0])
    Early_Arrivals_15= len(df15[df15['Difference'] > 0])
    print("Total Alaska Airlines flights that landed at JFK in 2015:",Total_15)
    print("Flights that arrived early in 2015:",Early_Arrivals_15)
    print("Flights that arrived more than 20 mins early in 2015:",Twenty_Mins_Early_15)
    

    # dictionary of lists  
 
    year =["2015","2016","2017","2018","2019"]
    total_flights= [Total_15, Total_16, Total_17, Total_18, Total_19]
    early_arrival=[Early_Arrivals_15,Early_Arrivals_16,Early_Arrivals_17,Early_Arrivals_18,Early_Arrivals_19]
    inflated_padding=[Twenty_Mins_Early_15,Twenty_Mins_Early_16,Twenty_Mins_Early_17,Twenty_Mins_Early_18,Twenty_Mins_Early_19]

    Carrier_Code=df['Carrier Code'][:5]
    dict = {'Carrier Code': Carrier_Code,'year': year, 'Total flights': total_flights, 'Early Arrivals': early_arrival, 'Inflated padding(>20mins early)': inflated_padding} 
    df = pd.DataFrame(dict) 
  
    # saving the dataframe 
    df.to_csv(output_fn,index=False)

# %%
analysis('../data/JetBlue_Airways.csv',r'../output/attemt.csv')
# Out:
# 201423
# Total Alaska Airlines flights that landed at JFK in 2019: 27805
# Flights that arrived early in 2019: 17966
# Flights that arrived more than 20 mins early in 2019: 7521
# Total Alaska Airlines flights that landed at JFK in 2018: 43196
# Flights that arrived early in 2018: 24721
# Flights that arrived more than 20 mins early in 2018: 7586
# Total Alaska Airlines flights that landed at JFK in 2017: 42660
# Flights that arrived early in 2017: 25406
# Flights that arrived more than 20 mins early in 2017: 9602
# Total Alaska Airlines flights that landed at JFK in 2016: 43693
# Flights that arrived early in 2016: 25808
# Flights that arrived more than 20 mins early in 2016: 6812
# Total Alaska Airlines flights that landed at JFK in 2015: 44068
# Flights that arrived early in 2015: 26937
# Flights that arrived more than 20 mins early in 2015: 8420

# %%
for filename in os.listdir('../data'):
    if filename.endswith('.csv'):
        print(filename)
        analysis('../data/'+filename,r'../output/'+filename)
# Out:
# American_Eagle.csv
# 12175
# Total Alaska Airlines flights that landed at JFK in 2019: 3273
# Flights that arrived early in 2019: 1978
# Flights that arrived more than 20 mins early in 2019: 703
# Total Alaska Airlines flights that landed at JFK in 2018: 5133
# Flights that arrived early in 2018: 2801
# Flights that arrived more than 20 mins early in 2018: 910
# Total Alaska Airlines flights that landed at JFK in 2017: 0
# Flights that arrived early in 2017: 0
# Flights that arrived more than 20 mins early in 2017: 0
# Total Alaska Airlines flights that landed at JFK in 2016: 0
# Flights that arrived early in 2016: 0
# Flights that arrived more than 20 mins early in 2016: 0
# Total Alaska Airlines flights that landed at JFK in 2015: 3768
# Flights that arrived early in 2015: 1937
# Flights that arrived more than 20 mins early in 2015: 375
# Endeavor_Air.csv
# 38476
# Total Alaska Airlines flights that landed at JFK in 2019: 14761
# Flights that arrived early in 2019: 9647
# Flights that arrived more than 20 mins early in 2019: 3258
# Total Alaska Airlines flights that landed at JFK in 2018: 23714
# Flights that arrived early in 2018: 15593
# Flights that arrived more than 20 mins early in 2018: 5436
# Total Alaska Airlines flights that landed at JFK in 2017: 0
# Flights that arrived early in 2017: 0
# Flights that arrived more than 20 mins early in 2017: 0
# Total Alaska Airlines flights that landed at JFK in 2016: 0
# Flights that arrived early in 2016: 0
# Flights that arrived more than 20 mins early in 2016: 0
# Total Alaska Airlines flights that landed at JFK in 2015: 0
# Flights that arrived early in 2015: 0
# Flights that arrived more than 20 mins early in 2015: 0
# United_Airlines.csv
# 3574
# Total Alaska Airlines flights that landed at JFK in 2019: 0
# Flights that arrived early in 2019: 0
# Flights that arrived more than 20 mins early in 2019: 0
# Total Alaska Airlines flights that landed at JFK in 2018: 0
# Flights that arrived early in 2018: 0
# Flights that arrived more than 20 mins early in 2018: 0
# Total Alaska Airlines flights that landed at JFK in 2017: 0
# Flights that arrived early in 2017: 0
# Flights that arrived more than 20 mins early in 2017: 0
# Total Alaska Airlines flights that landed at JFK in 2016: 0
# Flights that arrived early in 2016: 0
# Flights that arrived more than 20 mins early in 2016: 0
# Total Alaska Airlines flights that landed at JFK in 2015: 3573
# Flights that arrived early in 2015: 2483
# Flights that arrived more than 20 mins early in 2015: 960
# Virgin_America.csv
# 13828
# Total Alaska Airlines flights that landed at JFK in 2019: 0
# Flights that arrived early in 2019: 0
# Flights that arrived more than 20 mins early in 2019: 0
# Total Alaska Airlines flights that landed at JFK in 2018: 1041
# Flights that arrived early in 2018: 688
# Flights that arrived more than 20 mins early in 2018: 376
# Total Alaska Airlines flights that landed at JFK in 2017: 4368
# Flights that arrived early in 2017: 2622
# Flights that arrived more than 20 mins early in 2017: 1029
# Total Alaska Airlines flights that landed at JFK in 2016: 4412
# Flights that arrived early in 2016: 2704
# Flights that arrived more than 20 mins early in 2016: 800
# Total Alaska Airlines flights that landed at JFK in 2015: 4006
# Flights that arrived early in 2015: 2619
# Flights that arrived more than 20 mins early in 2015: 824
# US_Airways.csv
# 1421
# Total Alaska Airlines flights that landed at JFK in 2019: 0
# Flights that arrived early in 2019: 0
# Flights that arrived more than 20 mins early in 2019: 0
# Total Alaska Airlines flights that landed at JFK in 2018: 0
# Flights that arrived early in 2018: 0
# Flights that arrived more than 20 mins early in 2018: 0
# Total Alaska Airlines flights that landed at JFK in 2017: 0
# Flights that arrived early in 2017: 0
# Flights that arrived more than 20 mins early in 2017: 0
# Total Alaska Airlines flights that landed at JFK in 2016: 0
# Flights that arrived early in 2016: 0
# Flights that arrived more than 20 mins early in 2016: 0
# Total Alaska Airlines flights that landed at JFK in 2015: 1420
# Flights that arrived early in 2015: 770
# Flights that arrived more than 20 mins early in 2015: 177
# Skywest_Airlines.csv
# 3528
# Total Alaska Airlines flights that landed at JFK in 2019: 2053
# Flights that arrived early in 2019: 1186
# Flights that arrived more than 20 mins early in 2019: 292
# Total Alaska Airlines flights that landed at JFK in 2018: 1474
# Flights that arrived early in 2018: 755
# Flights that arrived more than 20 mins early in 2018: 147
# Total Alaska Airlines flights that landed at JFK in 2017: 0
# Flights that arrived early in 2017: 0
# Flights that arrived more than 20 mins early in 2017: 0
# Total Alaska Airlines flights that landed at JFK in 2016: 0
# Flights that arrived early in 2016: 0
# Flights that arrived more than 20 mins early in 2016: 0
# Total Alaska Airlines flights that landed at JFK in 2015: 0
# Flights that arrived early in 2015: 0
# Flights that arrived more than 20 mins early in 2015: 0
# PSA_Airlines.csv
# 621
# Total Alaska Airlines flights that landed at JFK in 2019: 254
# Flights that arrived early in 2019: 166
# Flights that arrived more than 20 mins early in 2019: 42
# Total Alaska Airlines flights that landed at JFK in 2018: 366
# Flights that arrived early in 2018: 209
# Flights that arrived more than 20 mins early in 2018: 80
# Total Alaska Airlines flights that landed at JFK in 2017: 0
# Flights that arrived early in 2017: 0
# Flights that arrived more than 20 mins early in 2017: 0
# Total Alaska Airlines flights that landed at JFK in 2016: 0
# Flights that arrived early in 2016: 0
# Flights that arrived more than 20 mins early in 2016: 0
# Total Alaska Airlines flights that landed at JFK in 2015: 0
# Flights that arrived early in 2015: 0
# Flights that arrived more than 20 mins early in 2015: 0
# Alaska_Airlines.csv
# 8384
# Total Alaska Airlines flights that landed at JFK in 2019: 3407
# Flights that arrived early in 2019: 2114
# Flights that arrived more than 20 mins early in 2019: 821
# Total Alaska Airlines flights that landed at JFK in 2018: 4082
# Flights that arrived early in 2018: 2458
# Flights that arrived more than 20 mins early in 2018: 993
# Total Alaska Airlines flights that landed at JFK in 2017: 421
# Flights that arrived early in 2017: 290
# Flights that arrived more than 20 mins early in 2017: 103
# Total Alaska Airlines flights that landed at JFK in 2016: 366
# Flights that arrived early in 2016: 276
# Flights that arrived more than 20 mins early in 2016: 127
# Total Alaska Airlines flights that landed at JFK in 2015: 107
# Flights that arrived early in 2015: 84
# Flights that arrived more than 20 mins early in 2015: 56
# JetBlue_Airways.csv
# 201423
# Total Alaska Airlines flights that landed at JFK in 2019: 27805
# Flights that arrived early in 2019: 17966
# Flights that arrived more than 20 mins early in 2019: 7521
# Total Alaska Airlines flights that landed at JFK in 2018: 43196
# Flights that arrived early in 2018: 24721
# Flights that arrived more than 20 mins early in 2018: 7586
# Total Alaska Airlines flights that landed at JFK in 2017: 42660
# Flights that arrived early in 2017: 25406
# Flights that arrived more than 20 mins early in 2017: 9602
# Total Alaska Airlines flights that landed at JFK in 2016: 43693
# Flights that arrived early in 2016: 25808
# Flights that arrived more than 20 mins early in 2016: 6812
# Total Alaska Airlines flights that landed at JFK in 2015: 44068
# Flights that arrived early in 2015: 26937
# Flights that arrived more than 20 mins early in 2015: 8420
# Republic_Airline.csv
# 4651
# Total Alaska Airlines flights that landed at JFK in 2019: 1804
# Flights that arrived early in 2019: 1211
# Flights that arrived more than 20 mins early in 2019: 334
# Total Alaska Airlines flights that landed at JFK in 2018: 2846
# Flights that arrived early in 2018: 1782
# Flights that arrived more than 20 mins early in 2018: 402
# Total Alaska Airlines flights that landed at JFK in 2017: 0
# Flights that arrived early in 2017: 0
# Flights that arrived more than 20 mins early in 2017: 0
# Total Alaska Airlines flights that landed at JFK in 2016: 0
# Flights that arrived early in 2016: 0
# Flights that arrived more than 20 mins early in 2016: 0
# Total Alaska Airlines flights that landed at JFK in 2015: 0
# Flights that arrived early in 2015: 0
# Flights that arrived more than 20 mins early in 2015: 0
# Hawaain_Airlines.csv
# 1632
# Total Alaska Airlines flights that landed at JFK in 2019: 243
# Flights that arrived early in 2019: 96
# Flights that arrived more than 20 mins early in 2019: 28
# Total Alaska Airlines flights that landed at JFK in 2018: 365
# Flights that arrived early in 2018: 202
# Flights that arrived more than 20 mins early in 2018: 54
# Total Alaska Airlines flights that landed at JFK in 2017: 353
# Flights that arrived early in 2017: 205
# Flights that arrived more than 20 mins early in 2017: 87
# Total Alaska Airlines flights that landed at JFK in 2016: 350
# Flights that arrived early in 2016: 209
# Flights that arrived more than 20 mins early in 2016: 78
# Total Alaska Airlines flights that landed at JFK in 2015: 320
# Flights that arrived early in 2015: 152
# Flights that arrived more than 20 mins early in 2015: 44
# American_Airlines.csv
# 80796
# Total Alaska Airlines flights that landed at JFK in 2019: 10571
# Flights that arrived early in 2019: 6669
# Flights that arrived more than 20 mins early in 2019: 2529
# Total Alaska Airlines flights that landed at JFK in 2018: 17445
# Flights that arrived early in 2018: 10929
# Flights that arrived more than 20 mins early in 2018: 4320
# Total Alaska Airlines flights that landed at JFK in 2017: 17023
# Flights that arrived early in 2017: 10180
# Flights that arrived more than 20 mins early in 2017: 3923
# Total Alaska Airlines flights that landed at JFK in 2016: 18649
# Flights that arrived early in 2016: 10876
# Flights that arrived more than 20 mins early in 2016: 3479
# Total Alaska Airlines flights that landed at JFK in 2015: 17107
# Flights that arrived early in 2015: 10761
# Flights that arrived more than 20 mins early in 2015: 4074
# Delta_Airlines.csv
# 139343
# Total Alaska Airlines flights that landed at JFK in 2019: 21743
# Flights that arrived early in 2019: 14970
# Flights that arrived more than 20 mins early in 2019: 5619
# Total Alaska Airlines flights that landed at JFK in 2018: 30025
# Flights that arrived early in 2018: 20699
# Flights that arrived more than 20 mins early in 2018: 8060
# Total Alaska Airlines flights that landed at JFK in 2017: 29593
# Flights that arrived early in 2017: 19713
# Flights that arrived more than 20 mins early in 2017: 8470
# Total Alaska Airlines flights that landed at JFK in 2016: 30256
# Flights that arrived early in 2016: 21153
# Flights that arrived more than 20 mins early in 2016: 7438
# Total Alaska Airlines flights that landed at JFK in 2015: 27725
# Flights that arrived early in 2015: 17731
# Flights that arrived more than 20 mins early in 2015: 5355
